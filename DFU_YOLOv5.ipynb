# %%
#!python -m pip install --upgrade pip

#!pip install tensorflow==2.3.1 

#!pip install tensorboard==2.4.1
#!pip install torch  

# WE RUN THIS BLOCK ONCE IN THE ENVIRONMENT JUST TO INSTALL MODULES

# %%
import torch

# %%
from IPython.display import Image

# %%
#!git clone https://github.com/ultralytics/yolov5

# WE RUN THIS ONCE IN EACH PROJECT TO GET YOLOV5

# %%
# %cd yolov5
# Out:
# /media/yearat/903C50093C4FE8B4/Users/Yearat/Documents/Jupyter Notebooks/499/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 415 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=30, batch_size=16, imgsz=415, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=True, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-7-31 torch 1.9.0+cu102 CUDA:0 (GeForce RTX 2060, 5926.1875MB)
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python detect.py --source runs/train/exp3/test/feet2.jpg --weights runs/train/exp3/weights/best.pt
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=runs/train/exp3/test/feet2.jpg, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-7-31 torch 1.9.0+cu102 CUDA:0 (GeForce RTX 2060, 5926.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /media/yearat/903C50093C4FE8B4/Users/Yearat/Documents/Jupyter Notebooks/499/yolov5/runs/train/exp3/test/feet2.jpg: 448x640 Done. (0.009s)
# Results saved to runs/detect/exp
# Done. (0.015s)
